# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

CSV_FILE = "gemini-2.5-flash.csv"
MODEL = CSV_FILE.replace(".csv","")
GENERAL_DATAFRAME_PATH = "results.csv"
pipelines_lst = [
                 "baseline",
                 "bm25", 
                 "dense",
                 "hybrid"
                ]

try:
    df = pd.read_csv(CSV_FILE)
    print(f"Loaded {len(df)} records from {CSV_FILE}")
except FileNotFoundError:
    print("CSV file not found. Run main.py")
# Out:
# /home/l4t8/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# Loaded 200 records from gemini-2.5-flash.csv

# %%
df
# Out:
#      question_number              pipeline  correct predicted ground_truth  \
# 0                  1  Baseline (Zero-shot)     True         C            C
# 1                  2  Baseline (Zero-shot)    False     ERROR            C
# 2                  3  Baseline (Zero-shot)    False     ERROR            B
# 3                  4  Baseline (Zero-shot)     True         D            D
# 4                  5  Baseline (Zero-shot)     True         C            C
# ..               ...                   ...      ...       ...          ...
# 195               46            Hybrid RAG     True         C            C
# 196               47            Hybrid RAG     True         B            B
# 197               48            Hybrid RAG     True         B            B
# 198               49            Hybrid RAG     True         C            C
# 199               50            Hybrid RAG     True         C            C
#
#                                                  quote  \
# ...

# %% [markdown]
#  ## PREPROCESS: Clean Data for Plotting

# %%
df = df.rename(columns={'correct': 'score'})
df['score'] = df['score'].astype(int)

if 'run_timestamp' in df.columns:
    df['run_timestamp'] = pd.to_datetime(df['run_timestamp'])

df.loc[59:60,:]
# Out:
#     question_number  pipeline  score predicted ground_truth  \
# 59               10  BM25 RAG      1         C            C
# 60               11  BM25 RAG      1         C            C
#
#                                                 quote  \
# 59  In contrast, a compression rate of64appears to...
# 60  These passages often exhibit low semantic simi...
#
#                        source   latency       run_timestamp
# 59  2509.01092v2.pdf, Page: 6  2.323209 2025-11-30 12:55:12
# 60  2509.01092v2.pdf, Page: 0  4.763180 2025-11-30 12:55:12

# %% [markdown]
# ## Current data analysis

# %%
plt.figure(figsize=(8, 5)) 

sns.barplot(
    data=df, 
    x="pipeline", 
    y="score", 
    hue="pipeline", 
    palette="viridis",
    errorbar=None
)

plt.title("Average Accuracy by Pipeline")
plt.ylabel("Accuracy")
plt.ylim(0, 1.1)

plt.show()

# %% [markdown]
# ## General data analysis

# %%
if not os.path.exists(GENERAL_DATAFRAME_PATH):
    rows = ['Baseline (Zero-shot)', 'Dense RAG', 'BM25 RAG', 'Hybrid RAG']
    cols = [
        'pro_acc', 'pro_count', 
        'flash_acc', 'flash_count', 
        'thinking_acc', 'thinking_count',
    ]
    general_df = pd.DataFrame(0.0, index=rows, columns=cols)

    general_df['last_run_timestamp'] = pd.Timestamp("2000-01-01")
else:
    general_df = pd.read_csv(GENERAL_DATAFRAME_PATH)
    
general_df
# Out:
#                       pro_acc  pro_count  flash_acc  flash_count  \
# Baseline (Zero-shot)      0.0        0.0        0.0          0.0
# Dense RAG                 0.0        0.0        0.0          0.0
# BM25 RAG                  0.0        0.0        0.0          0.0
# Hybrid RAG                0.0        0.0        0.0          0.0
#
#                       thinking_acc  thinking_count last_run_timestamp
# Baseline (Zero-shot)           0.0             0.0         2000-01-01
# Dense RAG                      0.0             0.0         2000-01-01
# BM25 RAG                       0.0             0.0         2000-01-01
# Hybrid RAG                     0.0             0.0         2000-01-01

# %% [markdown]
# ## Updating the general dataframe with the new information

# %%
current_run_stats = df.groupby('pipeline')['score'].mean()

df_time = pd.to_datetime(df['run_timestamp']).max()

if 'last_run_timestamp' in general_df.columns:
    general_df_time = pd.to_datetime(general_df['last_run_timestamp']).max()
else:
    general_df_time = pd.Timestamp.min # Handle case where master is empty

if df_time <= general_df_time:
    print(f"Data from {df_time} is older than last update ({general_df_time})")
else:
    target_prefix = None
    
    match MODEL:
        case 'gemini-2.5-flash':
            target_prefix = 'flash'
        case 'gemini-2.5-pro':
            target_prefix = 'pro'
        case 'gemini-2.0-flash-thinking-exp-01-21':
            target_prefix = 'thinking'
        case _:
            print(f"Error: Model '{MODEL}' not recognised in scoreboard columns.")

    if target_prefix:
        acc_col = f"{target_prefix}_acc"
        count_col = f"{target_prefix}_count"

        for pipeline, new_acc in current_run_stats.items():
            if pipeline in general_df.index:
                old_acc = general_df.loc[pipeline, acc_col]
                old_count = general_df.loc[pipeline, count_col]

                new_count = old_count + 1
                updated_acc = ((old_acc * old_count) + new_acc) / new_count

                general_df.loc[pipeline, acc_col] = updated_acc
                general_df.loc[pipeline, count_col] = new_count
                
                print(f"   -> {pipeline}: {old_acc:.2f} => {updated_acc:.2f} (Runs: {new_count})")

        general_df['last_run_timestamp'] = df_time

general_df
# Out:
# Data from 2025-11-30 13:06:34 is older than last update (2025-11-30 13:06:34)
#                       pro_acc  pro_count  flash_acc  flash_count  \
# Baseline (Zero-shot)      0.0        0.0       0.30          1.0
# Dense RAG                 0.0        0.0       0.82          1.0
# BM25 RAG                  0.0        0.0       0.88          1.0
# Hybrid RAG                0.0        0.0       0.90          1.0
#
#                       thinking_acc  thinking_count  last_run_timestamp
# Baseline (Zero-shot)           0.0             0.0 2025-11-30 13:06:34
# Dense RAG                      0.0             0.0 2025-11-30 13:06:34
# BM25 RAG                       0.0             0.0 2025-11-30 13:06:34
# Hybrid RAG                     0.0             0.0 2025-11-30 13:06:34

# %% [markdown]
# ## Analysis of the final general dataframe

# %%
plot_data = general_df.reset_index().rename(columns={'index': 'pipeline'})
plot_data
# Out:
#                pipeline  pro_acc  pro_count  flash_acc  flash_count  \
# 0  Baseline (Zero-shot)      0.0        0.0       0.30          1.0
# 1             Dense RAG      0.0        0.0       0.82          1.0
# 2              BM25 RAG      0.0        0.0       0.88          1.0
# 3            Hybrid RAG      0.0        0.0       0.90          1.0
#
#    thinking_acc  thinking_count  last_run_timestamp
# 0           0.0             0.0 2025-11-30 13:06:34
# 1           0.0             0.0 2025-11-30 13:06:34
# 2           0.0             0.0 2025-11-30 13:06:34
# 3           0.0             0.0 2025-11-30 13:06:34

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
fig.suptitle('RAG Model Performance Benchmark', fontsize=16)

sns.barplot(
    data=plot_data, 
    x="pipeline", 
    y="pro_acc", 
    hue="pipeline", 
    palette="Blues_d", 
    legend=False, 
    ax=axes[0]
)
axes[0].set_title("Pro Model Accuracy")
axes[0].set_ylim(0, 1.0)
axes[0].set_ylabel("Accuracy")

sns.barplot(
    data=plot_data, 
    x="pipeline", 
    y="flash_acc", 
    hue="pipeline", 
    palette="Greens_d", 
    legend=False, 
    ax=axes[1]
)
axes[1].set_title("Flash Model Accuracy")
axes[1].set_ylim(0, 1.0)
axes[1].set_ylabel("")

sns.barplot(
    data=plot_data, 
    x="pipeline", 
    y="hard_acc", 
    hue="pipeline", 
    palette="Reds_d", 
    legend=False, 
    ax=axes[2]
)
axes[2].set_title("Hard Questions Accuracy")
axes[2].set_ylim(0, 1.0)
axes[2].set_ylabel("")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 30
#      27 axes[1].set_ylim(0, 1.0)
#      28 axes[1].set_ylabel("")
# ---> 30 sns.barplot(
#      31     data=plot_data,
#      32     x="pipeline",
#      33     y="hard_acc",
#      34     hue="pipeline",
#      35     palette="Reds_d",
#      36     legend=False,
#      37     ax=axes[2]
#      38 )
#      39 axes[2].set_title("Hard Questions Accuracy")
#      40 axes[2].set_ylim(0, 1.0)
#
# File ~/.local/lib/python3.10/site-packages/seaborn/categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# ...
